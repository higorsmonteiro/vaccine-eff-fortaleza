# %% [markdown]
# # Lib

# %%
import os
import uuid
import numpy as np
import pandas as pd
import datetime as dt

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <img src="flow_codigo_db.png" width=600 height=600 >

# %% [markdown]
# <img src="matching2.png" width=800 height=600 >

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Vacine Já

# %%
fname_vacineja = os.path.join("..", "..", "..", "data", "vacinado_obito", "cadastrados_vacineja_202110111044.csv")
df_vacineja = pd.read_csv(fname_vacineja, delimiter=";", nrows=15)
df_vacineja_size = pd.read_csv(fname_vacineja, delimiter=";", nrows=None, usecols=["cpf"])

# %%
print(df_vacineja_size.shape[0])
df_vacineja[:5]
# Out:
# 1882607
#                                      nome          cpf data_nascimento  \
# 0                  EDILENE GOMES DA SILVA   4119600327      1974-10-20
# 1        JACKSON BRUNO DOS SANTOS MIRANDA   4285392380      1989-09-07
# 2  ANTONIA IEDA DE SALES LADISLAU DE LIMA  64130223372      1976-12-08
# 3        MARIA CLEIDE NASCIMENTO DA SILVA  58374531304      1975-12-20
# 4            ANTONIA ALYNNE DA SILVA LIMA   3687378373      1994-08-27
#
#            bairro     cidade sexo           created_at  \
# 0         PASSARE  FORTALEZA    F  2021-05-26 00:00:00
# 1      JANGURUSSU  FORTALEZA    M  2021-04-04 00:00:00
# 2  BARRA DO CEARA  FORTALEZA    F  2021-06-04 00:00:00
# 3      JANGURUSSU  FORTALEZA    F  2021-08-04 00:00:00
# 4      BONSUCESSO  FORTALEZA    F  2021-03-26 00:00:00
#
#                       nome_mae
# 0     LUCINEIDE GOMES DA SILVA
# 1     MARIA EUGENIA DOS SANTOS
# 2  TEREZINHA DE SALES LADISLAU
# 3                 MARIA CLEIDE
# 4          ADELIA ANA DA SILVA

# %% [markdown]
# ## Vacinados

# %%
fname_vacinados = os.path.join("..", "..", "..", "data", "vacinado_obito", "vacinados_d1d2_update_Sep2_2021.csv")
df_vacinados = pd.read_csv(fname_vacinados, delimiter=",", dtype={"cpf": str}, nrows=15, index_col=0)
df_vacinados_size = pd.read_csv(fname_vacinados, delimiter=",", usecols=["cpf"])
# Out:
# C:\Users\higor.monteiro\Miniconda3\envs\geopandas_testenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(df_vacinados_size.shape[0])
df_vacinados[:5]
# Out:
# 1831084
#                                   nome          cpf sexo data nascimento  \
# 0                  PALOMA SILVA BASTOS  07139828377    F      1999-09-17
# 1  FRANCISCA ELIZABETH FERREIRA CAMILO  60660696320    F      1993-10-05
# 2            MARIA CLARICE SILVA COSTA  09130985315    F      1940-02-17
# 3          PRISCILA MENEZES DEOLIVEIRA  06560411370    F      1994-05-10
# 4             MAURICIO VIEIRA DA SILVA  56718500372    M      1973-11-10
#
#       data D1     data D2     vacina fornecedor  idade anos  faixa etaria  \
# 0  2021-08-14         NaN     PFIZER     PFIZER          21  20 A 24 ANOS
# 1  2021-07-21         NaN     PFIZER     PFIZER          27  25 A 29 ANOS
# 2  2021-03-22  2021-04-03  CORONAVAC   BUTANTAN          81  80 A 84 ANOS
# 3  2021-07-30  2021-08-27  CORONAVAC   BUTANTAN          27  25 A 29 ANOS
# 4  2021-05-20  2021-08-04     PFIZER     PFIZER          47  45 A 49 ANOS
#
# ...

# %%
df_vacinados.isnull().sum()
# Out:
# nome                 0
# cpf                  0
# sexo                 0
# data nascimento      0
# data D1              0
# data D2              7
# vacina               0
# fornecedor           0
# idade anos           0
# faixa etaria         0
# bairro               0
# bairro id            1
# tipo atendimento     0
# tipo usuario         0
# grupo prioritario    0
# grupo atendimento    0
# dtype: int64

# %% [markdown]
# ## Gal

# %%
fname_gal = os.path.join("..", "..", "..", "data", "testes_covid19", "testes_gal_JAN_AGO2021.csv")
df_gal = pd.read_csv(fname_gal, delimiter=",", nrows=15, index_col=0)
df_gal_size = pd.read_csv(fname_gal, delimiter=",", usecols=["Status Exame"])

# %%
print(df_gal_size.shape[0])
df_gal[:5]
# Out:
# 366981
#    Index tabela original    Requisição Requisição Correlativo (S/N)  \
# 0                      0  210154000349                            N
# 1                      1  210156000227                            N
# 2                      2  210155000428                            N
# 3                      3  210190000171                            N
# 4                      4  210159000856                            N
#
#    Regional de Cadastro                    Laboratório de Cadastro  \
# 0                     1     UNIDADE PRONTO ATENDIMENTO JOSE WALTER
# 1                     1    UNIDADE PRONTO ATENDIMENTO AUTRAN NUNES
# 2                     1  UNIDADE PRONTO ATENDIMENTO CONJUNTO CEARA
# 3                     1   UNIDADE DE PRONTO ATENDIMENTO VILA VELHA
# 4                     1      UNIDADE PRONTO ATENDIMENTO JANGURUSSU
#
#    CNES Laboratório de Cadastro                        Unidade Solicitante  \
# ...

# %% [markdown]
# ## IntegraSUS

# %%
fname_integra = os.path.join("..", "..", "..", "data", "testes_covid19", "base_dados_integrasus_fortaleza_final.csv")
df_integra = pd.read_csv(fname_integra, delimiter=",", nrows=15, index_col=0)
df_integra_size = pd.read_csv(fname_integra, delimiter=",", usecols=["id_esus"])

# %%
print(df_integra_size.shape[0])
df_integra[:5]
# Out:
# 182073
#            id                   codigo_paciente  \
# 0  1105454769  000031a4ed0718fe9c8d3dfef523c850
# 1  1105575430  0001846c71bb644266e8f7c43458af31
# 2  1105488924  0001c767f54644e351b441e9dc62cf66
# 3  1105498107  0001f632bda731380d0ee25a685fd44a
# 4  1104222431  0001fbe0da8f4009c8ceb1a427627653
#
#                        codigo_obito  id_redcap  classificacao_estado_redcap  \
# 0  c2d850bea34a750409aeb1847a99e0c2        NaN                          NaN
# 1  2c56d9fb31aace17578b2aeb9d4c79cf        NaN                          NaN
# 2  0fc4604428eca30f87b3f7a74cf669c4        NaN                          NaN
# 3  149384e9363304f15101078759650794        NaN                          NaN
# 4  15bd4bbb5c2db08a908fd38b725e3701        NaN                          NaN
#
#         id_esus classificacao_estado_esus  classificacao_final_esus  \
# 0           NaN                       NaN                       NaN
# 1           NaN                       NaN                       NaN
# ...

# %% [markdown]
# ## Deaths covid (SIM)

# %%
fname_covid = os.path.join("..", "..", "..", "data", "obitos_covid19", "base_dados_obitos_cevepi.csv")
df_covid = pd.read_csv(fname_covid, delimiter=";", nrows=None, encoding="latin")
# Out:
# C:\Users\higor.monteiro\Miniconda3\envs\geopandas_testenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (52,98,99,113) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(df_covid.shape[0])
df_covid.iloc[:5,4:]
# Out:
# 11386
#    numerodo  nu_requisicao_lab  id_geo                            nome  sexo  \
# 0  29582542                NaN     NaN  CARMEZITA SANTOS DO NASCIMENTO   FEM
# 1  31486151                NaN     NaN      ALDEMIR RODRIGUES DE BRITO  MASC
# 2  29560445                NaN     NaN            ZULEIDE BORGES MOURA   FEM
# 3  29586834                NaN     NaN          IVONETE ROCHA PRACIANO   FEM
# 4  29606162                NaN     NaN      TARCILIO RODRIGUES BATISTA  MASC
#
#   data_nascimento                          nome_mae  idade_anos  nu_idade_n  \
# 0      03/11/1963                               NaN          56      4056.0
# 1      27/05/1964       BERENICE RODRIGUES DE BRITO          57      4057.0
# 2             NaN                               NaN          84      4084.0
# 3      08/05/1929              EROTILDES DIAS ROCHA          90      4090.0
# 4      27/10/1970  MARIA DO CARMO RODRIGUES BATISTA          49      4049.0
#
# ...

# %% [markdown]
# ## Death geral

# %%
fname_cart = os.path.join("..", "..", "..", "data", "obitos_cartorios", "obitos_cartorios_joined.csv")
df_cart = pd.read_csv(fname_cart, delimiter=",", nrows=None, dtype={"cpf": str}, index_col=0)
# Out:
# C:\Users\higor.monteiro\Miniconda3\envs\geopandas_testenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(df_cart.shape[0])
df_cart[:5]
# Out:
# 39612
#                                                    nome  livro  folha   termo  \
# index original
# 0               MELQUISEDEQUE ALVES CAVALCANTE DA SILVA   13.0  249.0  6301.0
# 1                              JOSÉ HUGO VIANA MESQUITA   13.0  245.0  6297.0
# 2                          FRANCE MARIA AMORIM PATRICIO   13.0  247.0  6299.0
# 3                             MARIA JOSÉ CARNEIRO GIRÃO   13.0  244.0  6296.0
# 4                              DERMIVAL CAMPOS NOGUEIRA   13.0  242.0  6294.0
#
#                data nascimento data falecimento                    genitor 1  \
# index original
# 0                   20/05/1999       01/01/2020  Mário Jorge da Silva Paixão
# 1                   09/05/1951       02/01/2020  Francisco Osmar de Mesquita
# 2                   11/04/1977       02/01/2020     Raimundo Bianor Patricio
# 3                   06/07/1931       02/01/2020    Benigno Carneiro de Sousa
# ...

# %%
eli = pd.read_csv("../output/eligibility_population.csv")
eli["uuid"] = eli["cpf"].apply(lambda x: uuid.uuid4())
eli = eli.drop(["nome", "cpf", "data_nascimento", "nome_mae"], axis=1)
# Out:
# C:\Users\higor.monteiro\Miniconda3\envs\geopandas_testenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (22,23,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
eli[:5]
# Out:
#            bairro sexo           created_at   data D1(VACINADOS)  \
# 0         PASSARE    F  2021-05-26 00:00:00  2021-05-29 00:00:00
# 1      JANGURUSSU    M  2021-04-04 00:00:00  2021-06-04 00:00:00
# 2  BARRA DO CEARA    F  2021-06-04 00:00:00  2021-06-19 00:00:00
# 3      JANGURUSSU    F  2021-08-04 00:00:00  2021-08-09 00:00:00
# 4      BONSUCESSO    F  2021-03-26 00:00:00  2021-07-27 00:00:00
#
#     data D2(VACINADOS) vacina(VACINADOS) fornecedor(VACINADOS)  \
# 0  2021-08-27 00:00:00       ASTRAZENECA               FIOCRUZ
# 1  2021-08-09 00:00:00       ASTRAZENECA               FIOCRUZ
# 2                  NaN       ASTRAZENECA               FIOCRUZ
# 3                  NaN         CORONAVAC              BUTANTAN
# 4                  NaN       ASTRAZENECA               FIOCRUZ
#
#    idade anos(VACINADOS) faixa etaria(VACINADOS) bairro(VACINADOS)  ...  \
# 0                   46.0            45 A 49 ANOS           PASSARE  ...
# ...

# %%
eli.to_csv(os.path.join("..", "output", "eligibility_population_filter.csv"))
